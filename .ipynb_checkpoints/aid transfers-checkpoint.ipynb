# %%
import pandas as pd
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import re
import networkx as nx
import csv
import json

import plotly.plotly as py
import plotly.tools as tls
from plotly.graph_objs import *

mpl_fig = plt.figure()

# %%
data_path = r"/Users/christopherallison/Documents/Coding/Data/"

# %%
nodes = []
edges = []
details = {}

G = nx.DiGraph()

# %%
# Read CSV of UID and Colleagues and create nodes & edges

with open(data_path+"aid_tables.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        G.add_edge(row['Source'], row['Target'], weight=row['Weight'])

# %%
# Out:
# [['Entry', 'SeeAlso'],
#  ["Valind's Winter Wastes", 'Valind'],
#  ["Valind's Winter Wastes", 'Genertela'],
#  ["Valind's Winter Wastes", 'North Pent'],
#  ["Valind's Winter Wastes", "Valind's Glacier"],
#  ["Valind's Winter Wastes", "Valind's Wastes"],
#  ['Valka Runewolf', 'Balazar (country)'],
#  ['Valkaro', 'Ambovombe'],
#  ['Valkaro', 'East Isles'],
#  ['Valkaro', 'Saint'],
#  ['Valley of Cradles', 'Zola Fel Valley'],
#  ['Valley of Hammers', 'Greatway'],
#  ['Valley of Hammers', 'Balazar (country)'],
#  ['Valley of Hammers', 'Mostali'],
#  ['Valley of the Chalk Man', 'Far Point'],
#  ['Valley of the Chalk Man', 'Sartar'],
#  ['Valstach', 'Prax'],
#  ['Valsterius', 'Storm Age'],
#  ['Valsterius', 'Lesser Darkness'],
#  ['Valsterius', 'Anaxial'],
#  ['Valsterius', 'Khordeneus'],
#  ['Valsterius', 'Murharzarm'],
#  ['Valsterius', 'Pene'],
#  ['Valtorwal', 'Svalak'],
#  ['Valtorwal', 'Old Seshnela'],
#  ['Value Trollkin', 'Trollkin'],
#  ['Value Trollkin', 'Enlo'],
#  ['Value Trollkin', 'Kyger Litor'],
#  ['Valzain', 'Vormain'],
#  ['Valzain', 'Emperor'],
#  ['Vampire Kings', 'Dawn Age'],
#  ['Vampire Kings', 'Tanisor'],
#  ['Vampire Kings', 'Gbaji Wars'],
#  ['Vampire Kings', 'Arkat'],
#  ['Vampire Kings', 'Vampires'],
#  ['Vamargic Eye-necklace', 'Great Trolls'],
#  ['Vamargic Eye-necklace', 'Kajak-ab the Brain-eater'],
#  ['Vamargic Eye-necklace', 'Zorak Zoran'],
#  ['Vamargic Eye-necklace', 'Cave Trolls'],
#  ['Vamargic Eye-necklace', 'Troll Woods'],
#  ['Vampire Kings', 'Vampire'],
#  ['Vampires', 'Vampire'],
#  ['Vampire', 'Undead'],
#  ['Undead', 'Vampire'],
#  ['Undead', 'Zombie'],
#  ['Undead', 'Mummy'],
#  ['Vampire King of Tanisor', 'Vampire Kings'],
#  ['Vampire King of Tanisor', 'Tanisor'],
#  ['Vampire King of Tanisor', 'Gbaji Wars'],
#  ['Vampire Legion', 'Vampires'],
#  ['Vampire of Gork Hills', 'Balazar (country)'],
#  ['Gork Hills', 'Elder Wilds'],
#  ['Vamth', 'Luathela'],
#  ['Vamth', 'Rhylor'],
#  ['Vamth', 'Gates of Dusk'],
#  ['Vanarthurd', 'Guardian of the West'],
#  ['Vanarthurd', 'Scarlet Camp'],
#  ['Sovereignty', 'Dara Happa'],
#  ['Vanch Kingdom', 'Lunar Provinces'],
#  ['Vanch Kingdom', 'Vanch'],
#  ['Vanarthurd', 'Sovereignty'],
#  ['Vanch Kingdom', 'Bikhy'],
#  ['Vanch Kingdom', 'Hill of Gold'],
#  ['Vandana the Virgin', 'Machine Wars'],
#  ['Vandana the Virgin', 'Kethaela'],
#  ['Vaneekara the Hurler', 'Vaneekara'],
#  ['Varganthar, the Unconquerable Knight', 'Dawn Age'],
#  ['Varganthar, the Unconquerable Knight', 'Gbaji Wars'],
#  ['Varganthar, the Unconquerable Knight', 'Akem'],
#  ['Varganthar, the Unconquerable Knight', 'Fronela'],
#  ['Varganthar', 'Fronela'],
#  ['Unconquerable Knight', 'Varganthar'],
#  ['Vargantyr Too Big', 'Tastolar'],
#  ['Vargantyr Too Big', 'Porent'],
#  ['Vargantyr Too Big', 'Fronela'],
#  ['Vargast Two-ring', 'Dawn Age'],
#  ['Vargast Two-ring', 'Dragon Pass'],
#  ['Vargast Two-ring', 'Harmast Barefoot'],
#  ['Vargast Two-ring', 'Lokamayadon'],
#  ["Vargov's Due", 'Storm Bull'],
#  ["Vargov's Due", 'Prax'],
#  ['Varloz Gilthelm', 'Black Rock'],
#  ['Varloz Gilthelm', 'Sun County'],
#  ['Varmand', 'Sartar'],
#  ['Varmand', 'Quiviniland'],
#  ['Old Man Varmand', 'Varmand'],
#  ['Varmand', 'Old Man Varmand'],
#  ['Varmand', 'Orlev'],
#  ['Varmandi', 'Varmand'],
#  ['Varmandi', 'Sartar'],
#  ['Varmandi', 'Colymar (tribe)'],
#  ['Varnan of Cafol', 'Cafol'],
#  ['Varnan of Cafol', 'Saird'],
#  ['Varnarn of Elz Ast', 'Elz Ast'],
#  ['Varnarn of Elz Ast', 'Peloria'],
#  ['Varnaro', 'Riverjoin'],
#  ['Varnaro', 'Janube River Valley'],
#  ['Varnaro', 'Arrolian City States'],
#  ['Varnaro of Riverjoin', 'Varnaro'],
#  ['Varnatol', 'Composite History of Dragon Pass'],
#  ['Varnatol', 'Densesros'],
#  ['Varnatol', 'Durtarl'],
#  ['Varnatol', 'Penraltan the Killer'],
#  ['Varnatol', 'Dwernapple'],
#  ['Wood-Hackers', 'Dwernapple'],
#  ['Wood-Hackers', 'Grazeland'],
#  ['Wood-Hackers', 'Varnatol'],
#  ['Wood-Hackers', 'Penraltan the Killer'],
#  ['Wood-Hackers', 'Argrath'],
#  ['Varnaval', 'Voriof'],
#  ['Varnaval', 'Good Shepherd'],
#  ['Varnaval', 'Iron Ram'],
#  ['Varnaval', 'Storm Tribe'],
#  ['Varnaval', 'Orlanth Pantheon'],
#  ['Varnous', 'Neasha of Rhigos'],
#  ['Varnous', 'Rhigos'],
#  ['Sir Varnous', 'Varnous'],
#  ['Varskolin', 'Pasos'],
#  ['Varskolin', 'Seshnela'],
#  ['Varskolin', 'Egarun'],
#  ['Varsmar Barntadusson', 'Colymar (tribe)'],
#  ['Varsmar Barntadusson', 'Barntadus'],
#  ['Varsmar Barntadusson', 'Orlmarth'],
#  ['Varsmar Barntadusson', 'Beastmen'],
#  ['Varsmar Barntadusson', 'Zombie'],
#  ['Barntadus', 'Colymar (tribe)'],
#  ['Barntadus', 'Varsmar Barntadusson'],
#  ['Varstach of Pavis', 'Pavis City'],
#  ['Varstach of Pavis', 'Valstach'],
#  ['Varstapoor', 'Arim'],
#  ['Varstapoor', 'Tarsh'],
#  ["Vaneekara's Shot", 'Underworld'],
#  ["Vaneekara's Shot", 'Wonderhome'],
#  ['Wonderhome', 'Underworld'],
#  ['Wonderhome', 'Trolls'],
#  ["Vaneekara's Shot", 'Vaneekara'],
#  ["Vaneekara's Shot", 'Eristi the Doubter'],
#  ["Vaneekara's Shot", 'Old Man'],
#  ['Vanestalavus', 'Dara Happa'],
#  ['Vanestalavus', 'Darkness Age'],
#  ['Vanestalavus', 'Manimat'],
#  ['Vanestalavus', 'Hurdendus'],
#  ['Vania', 'Trilus'],
#  ['Vania', 'Balazar (country)'],
#  ['Vania, Queen of Trilus', 'Vania'],
#  ['Queen of Trilus', 'Vania'],
#  ['Queen of Trilus', 'Trilus'],
#  ['Yalaring', 'Trilus'],
#  ['Vania', 'Yalaring'],
#  ['Vania', 'Gan-Gan'],
#  ['Vania', 'Melisseria'],
#  ['Yalvann', 'Trilus'],
#  ['Vania', 'Djimm Mith'],
#  ['Vania', 'Rhegus Whitehair'],
#  ['Yalvann', 'Vania'],
#  ['Vania', 'Yalvann'],
#  ['Vanish Rib-Crusher', 'Prax'],
#  ['Vanish Rib-Crusher', 'Bison Tribe'],
#  ['Vanstal', 'Esel'],
#  ['Vanstal', 'Doresel'],
#  ['Vanstal', 'Bisos'],
#  ['Vanstal', 'Peloria'],
#  ['Vanstan the Elder', "Mirin's Cross"],
#  ['Vanstan the Elder', 'Saird'],
#  ['Vanstan the Elder', 'Ages of the World'],
#  ['Vantaros', 'Vantaros tribal lands'],
#  ['Vantaros', 'Far Point'],
#  ['Vantaros', 'Aldachur'],
#  ['Vantaros', 'Sartar'],
#  ['Vantaros', 'Harvar Ironfist'],
#  ['Vantaros Tribe', 'Vantaros'],
#  ['Varajiia Nopor', 'EWF'],
#  ['Varajiia Nopor', 'Prax'],
#  ['Varajiia Nopor', 'Waha'],
#  ['Varaneena Cow-eye', 'Bison Tribe'],
#  ['Varaneena Cow-eye', 'Prax'],
#  ['Varaneena Cow-eye', 'Narmeed Whirlvishbane'],
#  ['Varaneena Cow-eye', 'Biturian Varosh'],
#  ["Pamalt's Necklace", 'Pamalt'],
#  ['Varama', "Pamalt's Necklace"],
#  ['Varama', 'Doraddi'],
#  ['Varama', 'Agimori'],
#  ['Varanae', 'Kumanku'],
#  ['Varanswal', 'Orik'],
#  ['Varanswal', 'Enkloso'],
#  ['Varanswal', 'God Learner Cities'],
#  ['Varanswal', 'Jogrampur'],
#  ['Varanswal', 'False Gods Revolt'],
#  ['Varanthis II', 'Varthanis II'],
#  ['Varchulanga', 'Seruvar'],
#  ['Varchulanga', 'Drospoly'],
#  ['Deepest Sea', 'Varchulanga'],
#  ['Deepest Sea', 'Drospoly'],
#  ['Varchulanga', 'Deepest Sea'],
#  ['Varchulanga', 'Kraken'],
#  ['Varchulanga', 'Leviathan'],
#  ['Varchulanga', 'Waertagi'],
#  ['Varganthar', 'Akem'],
#  ['Varganthar', 'Talor'],
#  ['Varganthar', 'Gbaji Wars'],
#  ['Varganthar', 'Dawn Age'],
#  ['Varganthar, the Unconquerable Knight', 'Varganthar'],
#  ['Varstapoor', 'Sorana Tor'],
#  ['Varstapoor', 'Vestenbora'],
#  ['Varstapoor', 'Falling Hills Battle'],
#  ['Vestenbora', 'Arim'],
#  ['Vestenbora', 'Sorana Tor'],
#  ['Vestenbora', 'Falling Hills Battle'],
#  ['Vestenbora', 'Varstapoor'],
#  ['Vestenbora', 'Tarsh'],
#  ['Vestenbora', 'Earth Twins'],
#  ['Varstapoor', 'Earth Twins'],
#  ['Varstari', 'Solanthi Lands'],
#  ['Varstari', 'Greymane'],
#  ['Varthulwal', 'Arolanit'],
#  ['Varthulwal', 'Brithini'],
#  ['Varthulwal', 'Waertagi Beacon'],
#  ['Varvachain Diggers', 'Kalali Erok'],
#  ['Vastako Indo', 'Pure Horse Tribe of Prax'],
#  ['Vastako Indo', 'Alavan Argay'],
#  ['Vatolagorinor', 'East Isles'],
#  ['Vedi Chain', 'East Isles'],
#  ['Vayobi', 'Kralorelan Dynasty'],
#  ['Vayobi', 'Emperor of Kralorela'],
#  ['Vashanti', 'Kralorelan Dynasty'],
#  ['Vashanti', 'Emperor of Kralorela'],
#  ['Veal', 'Seshnela'],
#  ['Vega Goldbreath', 'Sun County'],
#  ['Vega Goldbreath', 'Penta Goldbreath'],
#  ['Penta Goldbreath', 'Vega Goldbreath'],
#  ['Penta Goldbreath', 'Sun County'],
#  ['Penta Goldbreath', 'Ernalda'],
#  ['Vega Goldbreath', 'Yelmalio'],
#  ['Vega Goldbreath', 'Light Sons'],
#  ['Veldang (language)', 'Artmali'],
#  ['Veldang (language)', 'Fonrit'],
#  ['Veldang (language)', 'Veldang'],
#  ['Veldang (language)', 'Zamokil'],
#  ['Veldang (language)', 'Loper People'],
#  ['Veldang (language)', 'Melib'],
#  ['Velet Dehori', 'Rebel Gods'],
#  ['Velet Dehori', 'First Ring'],
#  ['Venderi', 'Grazeland'],
#  ['Venderi', 'Hiia Swordsman'],
#  ['Venderi', 'Feathered Horse Queen'],
#  ['Vendref', 'Grazeland'],
#  ['Vendref', 'Feathered Horse Queen'],
#  ['Vendreog', "Ygg's Isles"],
#  ['Vendreog', 'Loskalm'],
#  ['Veng', 'Dara Happa'],
#  ['Veng', 'Yelm Pantheon'],
#  ['Venharl Intagarnsson', 'Colymar (tribe)'],
#  ['Venharl Intagarnsson', 'Jenstali'],
#  ['Venharl', 'Venharl Running Fox'],
#  ['Venharl', 'Venharl Intagarnsson'],
#  ['Venharl', 'Venharl the Climber'],
#  ['Venharl the Climber', 'Karandoli'],
#  ['Venharl the Climber', 'Zarran War'],
#  ['Venharl the Climber', 'Robasart Broyansson'],
#  ['Venharl the Climber', 'Maniski Firebreath'],
#  ['Venharl', 'Venharl the Karandoli'],
#  ['Venharl the Karandoli', 'Karandoli'],
#  ['Venharl the Karandoli', 'Colymar (tribe)'],
#  ['Venharl the Climber', 'Argrath'],
#  ['Venharl the Climber', 'Yanioth Twosight'],
#  ['Goddess of Waters', 'Venperesha'],
#  ['Venperesha', 'Goddess of Waters'],
#  ['Venpereshan Sea', 'Venperesha'],
#  ['Venpereshan Sea', 'East Isles'],
#  ['Venpereshan Sea', 'Eastern Sea'],
#  ['Venperha', 'Venperesha'],
#  ['Venperhan Sea', 'Venpereshan Sea'],
#  ['Venperhan Sea', 'East Isles'],
#  ['Venperhan Sea', 'Eastern Sea'],
#  ['Venperhen Sea', 'Venpereshan Sea'],
#  ['Vent', 'Three Dragon Mountains'],
#  ['Vent', 'Caladra'],
#  ['Vent', 'Caladraland'],
#  ['Vent', 'High Temple'],
#  ['City of Raptors', 'Verapur'],
#  ['Verapur', 'City of Raptors'],
#  ['Raptors', 'Bird'],
#  ['Raptors', 'Verapur'],
#  ['Verapur', 'Raptors'],
#  ['Verapur', 'Blows from Within'],
#  ['Verapur', "Murharzarm's Good Land"],
#  ['Verapur', 'Dara Happa'],
#  ['Verapur', 'Ten Cities'],
#  ['Veredth', 'Terthinus'],
#  ['Veredth', 'Sea Gods'],
#  ['Veredthi', 'Naiads'],
#  ['Veredthi', 'Veredth'],
#  ['Father of Currents', 'Veredth'],
#  ['Verenmars', 'Saird'],
#  ['Verenmars', 'Sarenesh the New Ordanestyu'],
#  ['Verenmars', 'Sarenesh the Great Ass'],
#  ['Verenmars', 'EWF'],
#  ['Verenmars', 'Imperial Age'],
#  ['Vergenari', 'Finger Goddesses'],
#  ['Vergenari', 'Dara Happa'],
#  ['Vergenari', 'Gods Wall'],
#  ['Vergustus', 'Greater Darkness'],
#  ['Vergustus', 'Hill of Gold'],
#  ['Vergustus', 'Antirius'],
#  ['Vergustus', 'Manimat'],
#  ['Vergustus', 'Dara Happa'],
#  ['Verithurus', 'Yelm Pantheon'],
#  ['North White Planet', 'Verithurus'],
#  ['Verithurus', 'North White Planet'],
#  ['Verithurus', 'Umatum'],
#  ['Verithurus', 'Verithurusa'],
#  ['Original Planets', 'Verithurus'],
#  ['Verithurus', 'Original Planets'],
#  ['Verithurusa', 'Red Moon'],
#  ['Verithurusa', 'Zaytenera'],
#  ['Verithurusa', 'Sedenya'],
#  ['Verithurusa', 'Mernita'],
#  ['Verithurusa', 'Lesilla'],
#  ['Verithurus', 'Jernedeus'],
#  ['Verithurus', 'Jernotius'],
#  ['Verithurusus', 'Yelm Pantheon'],
#  ['Vertus', 'Dispenser of Horses'],
#  ['Vertus', 'Nattaus'],
#  ['Vertus', 'Dara Happa'],
#  ['Vertus', 'Dawn Age'],
#  ['Vertus', 'Plentonius'],
#  ['Vertus', 'Yunirtos'],
#  ['Prince of Yunirtos', 'Vertus'],
#  ['Prince of Yunirtos', 'Yunirtos'],
#  ['Yunirtos', 'Vertus'],
#  ['Verondum', 'Darjiin'],
#  ['Verondum', 'Suvaria'],
#  ['Verondum', 'SurEnslib'],
#  ['Verondum', 'Storm Age'],
#  ['Vesgarings', 'Brolia'],
#  ['Vesgarings', 'Anadiki'],
#  ['Vesgarings', 'Top of the World'],
#  ['Vesgarings', 'Peloria'],
#  ['Vesgarings', 'Orlanthi'],
#  ['Vesgarings', 'Vesgaringland'],
#  ['Veskerele', 'Veskerelgat'],
#  ['Veskerele', 'God Caves'],
#  ['Veskerele', 'Underworld'],
#  ['Veshtargos', 'Dawn Age'],
#  ['Veshtargos', 'Dara Happa'],
#  ['Veshtargos', 'Gray Age'],
#  ['Veshtargos', 'Vuranostum'],
#  ['Vessel of Light', 'Pubnashab'],
#  ['Vessel of Light', 'Teshnos'],
#  ['Vestanteland', 'Vestantes'],
#  ['Vestantes', 'Vingkotling Age'],
#  ['Vestantes', 'Aggar'],
#  ['Vestantes', 'Peloria'],
#  ['Vestantes', 'Vingkot'],
#  ['Vestante', 'Vingkot'],
#  ['Vestkarthan of the Deep', 'Lodril'],
#  ['Vestkarthan of the Deep', 'Quivin'],
#  ['Vestkarthan of the Deep', 'Umath'],
#  ['Vestkarthan of the Deep', 'Ga'],
#  ['Vestkarthan of the Deep', 'First Hospitality, the'],
#  ['Vettebbe', 'Arcos Valley'],
#  ['Vettebbe', 'Starlight Ancestors'],
#  ['Vettebbe', 'Hirenmador'],
#  ['Vettebbe', 'Horse Barbarians'],
#  ['Vestantes', 'Summer Tribes'],
#  ['Victors, The', 'Sun County'],
#  ['Vikkard', 'Kustria'],
#  ['Vikkard', 'Seshnela'],
#  ['Vikkard', 'Ulianus'],
#  ['Vikkard', 'Ralios'],
#  ['Vikkard', 'Safelster'],
#  ['Vile Thaws', 'North Pent'],
#  ['Vile Thaws', "Valind's Wastes"],
#  ['Vilgars', 'Gods War'],
#  ['Vilgars', 'Argrath'],
#  ['Vinakotal', 'Dara Happa'],
#  ['Vinakotal', 'Vingkot'],
#  ['Vinavale', 'Caladraland'],
#  ['Vinavale', 'Kethaela'],
#  ['Vinavale', 'Low Temple'],
#  ['Vindorhall', 'Ingolf Dragonfriend'],
#  ['Left Claw', 'Ingolf Dragonfriend'],
#  ['Left Claw', 'Vindorhall'],
#  ['Vindorhall', 'Ralios'],
#  ['Vindorhall', 'Noramland'],
#  ['Vindorhall', 'Delela'],
#  ['Vindorhall', 'Vindori'],
#  ['Vindori', 'Vindorhall'],
#  ['Vindori', 'Noramland'],
#  ['Vindori', 'Delela'],
#  ['Vindori', 'Ingolf Dragonfriend'],
#  ['Vindori', 'Imperial Age'],
#  ['Vindori', 'Cragspider'],
#  ['Vingan', 'Vinga'],
#  ['Vingkot', 'Vingkot the Victorious'],
#  ['Vingkot', 'Storm Era'],
#  ['Vingkot', 'Vingkotling Age'],
#  ['Vingkot', 'Storm Age'],
#  ['Vingkot', 'Orlanth'],
#  ['Vingkot the Victorious', 'Vingkot'],
#  ['Vingkot', 'Hengall Vingkotsson'],
#  ['Vingkot', 'Korol'],
#  ['Sons of Vingkot', 'Korol'],
#  ['Sons of Vingkot', 'Hengall Vingkotsson'],
#  ['Sons of Vingkot', 'Kodig'],
#  ['Sons of Vingkot', 'Jorganos Archer'],
#  ['Sons of Vingkot', 'Janard'],
#  ['Sons of Vingkot', 'Lastralgor'],
#  ['Vingkotling Age', 'Storm Age'],
#  ['Vingkotling Age', 'Storm Era'],
#  ['Vingkotlings', 'Orlanthi'],
#  ['Vingkotlings', 'Storm Age'],
#  ['Vingkotlings', 'Storm Era'],
#  ['Vingkotling Tribes', 'Kodigvari'],
#  ['Vingkotling Tribes', 'Koroltes'],
#  ['Vingkotling Tribes', 'Vestantes'],
#  ['Vingkotling Tribes', 'Penentelli'],
#  ['Vingkotling Tribes', 'Jorganostelli'],
#  ['Berenethtelli', 'Saird'],
#  ['Berenethtelli', 'Hyalorings'],
#  ['Berenethtelli', 'Redalda'],
#  ['Berenethtelli', 'Beren the Rider'],
#  ['Vingkotling Tribes', 'Orgorvaltes'],
#  ['Vingkotling Tribes', 'Berenethtelli'],
#  ['Vingkotling Tribes', 'Lastralgortelli'],
#  ['Orgorvaltes', 'Quiviniland'],
#  ['Orgorvaltes', 'Vingkotling Tribes'],
#  ['Vininna', 'Jarolar'],
#  ['Vininna', 'Jarosar'],
#  ['Vininna', 'Sartar'],
#  ['Viri of Orlanth', 'Heortland'],
#  ['Viri of Orlanth', 'Storm Mountains'],
#  ['Viri of Orlanth', 'Wind Children'],
#  ['Virtues of Hrestol', 'Malkioni'],
#  ['Virtues, Orlanthi', 'Heortlings'],
#  ['Visitors', 'Trowjang'],
#  ["Visitor's Gate", 'Palbar'],
#  ["Visitor's Gate", 'Oraya'],
#  ["Visitor's Gate", 'Lunar Empire'],
#  ['VioVanus', 'Idovanus'],
#  ['Virgin Goddesses', 'Voria'],
#  ['Virgin Goddesses', 'Babeester Gor'],
#  ['Virgin Goddesses', 'Ourania'],
#  ['Viridia Patroma', 'Patroma'],
#  ['Viridia Patroma', 'Pavis City'],
#  ['Viridia Patroma', 'Rich Hill'],
#  ['Viridia Patroma', 'Griselda'],
#  ['Viridian Magic', 'Zaktirra'],
#  ['Viridian Magic', 'Vormain'],
#  ['Virimakus', 'Vrimak'],
#  ['Virimakus', 'Vrimakus'],
#  ['Vistikos Left-eye', 'Vistikos'],
#  ['Vistikos', 'Vistikos Left-eye'],
#  ['Vistikos', 'EWF'],
#  ['Vistikos', 'Nochet'],
#  ['Vistikos', 'Kethaela'],
#  ['Vistikos', 'Bishopric of Nochet'],
#  ['Vistur', 'Dara Happa'],
#  ["Vith's Breath", 'Veldru'],
#  ['Vithela', 'Kralorela'],
#  ['Vithela', 'Vormain'],
#  ['Vithela', 'Kahar Sea'],
#  ['Vithela', 'East Isles'],
#  ['Vithela', 'Govmeranen'],
#  ['Vithelan Continent', 'Vithela'],
#  ['Vithelan Language', 'Vithelan'],
#  ['ViTuros', 'Turos'],
#  ['ViTuros', 'Peloria'],
#  ['ViTuros', 'Saird'],
#  ['ViTuros', 'Oraya'],
#  ['VLB', 'Minaryth Purple'],
#  ['Vladina', 'VLB'],
#  ['Vladina', 'Lhankor Mhy'],
#  ['Vivamort', 'Vampires'],
#  ['Vivamort', 'Undead'],
#  ['Vivamort', 'Chaos'],
#  ['Vizel', 'Kethaela'],
#  ['Vogarth the Strong Man', 'Vogarth'],
#  ['Vogarth the Strong Man', 'Esrolia'],
#  ['Vogarth the Strong Man', 'Silver Age'],
#  ['Vogarth', 'Vogarth the Strong Man'],
#  ['Vogarth', 'Esrolia'],
#  ['Vogarth', 'Silver Age'],
#  ['Voi', 'Seshnela'],
#  ['Voi', 'Tanier'],
#  ['Voi', 'Guilmarn'],
#  ['Void', 'Chaos'],
#  ['Voilor River', 'Maniria'],
#  ['Vol Ini', 'Overnighter'],
#  ['Vol Ini', 'Jolar'],
#  ['Volcanoes', 'Bluesmoke'],
#  ['Volcanoes', 'Vent'],
#  ['Bluesmoke', 'Volcanoes'],
#  ['Bluesmoke', 'Maniria'],
#  ['Volonne', "Kanthor's Islands"],
#  ['Volonne', 'Seshnela'],
#  ['Volonne', 'Pasos'],
#  ['Volsaxi', 'Marzeel Valley'],
#  ['Volsaxi', 'Whitewall'],
#  ['Volsaxi', 'Kurtali'],
#  ['Volsaxi', 'Curtali Tribal Lands'],
#  ['Volsaxi', 'Sylangi tribal lands'],
#  ['Volsaxi', 'Bacofi'],
#  ['Volsaxi', 'Broyan'],
#  ['Volsaxi', 'Tarkalor'],
#  ['Volsaxland', 'Volsaxiland'],
#  ['Volsaxland', 'Volsaxi'],
#  ['Volsaxland', 'Heortland'],
#  ['Volsaxiland', 'Volsaxi'],
#  ['Volsaxiland', 'Heortland'],
#  ['Vonagog', 'Konagog'],
#  ['Variant Army', 'Vonagog'],
#  ['Variant Army', 'Konagog'],
#  ['Vonlath', 'Dara Happa'],
#  ['Vonlath', 'Oslir Valley'],
#  ['Vonlath', 'Raibanth'],
#  ['Voralan', 'Voralans'],
#  ['Voralan', 'Black Elves'],
#  ["Vorala's Wish, Battle of", 'Umathela'],
#  ['Voranel', 'Lakrene'],
#  ['Voranel', 'Talastar'],
#  ['Voriof the Shepherd', 'Voriof'],
#  ['Vorlarian', 'Slorifings'],
#  ['Vorlatkantus', 'Gray Age'],
#  ['Vorlatkantus', 'Dara Happa'],
#  ['Vormain', 'Kahar Sea'],
#  ['Vormain', 'Sshorg Sea'],
#  ['Vormain', 'East Isles'],
#  ['Vormain', 'Telask'],
#  ['Vormain', 'Tsankht'],
#  ['Vormain', 'Zaktirra'],
#  ['Vormain pirates', 'Tsankht'],
#  ['Vormain', 'Valzain'],
#  ['Vormain pirates', 'Vormain'],
#  ['Vorstenans', 'Gray Age'],
#  ['Vorstenans', 'Dara Happa'],
#  ['Vorwaha Bisonlord', 'Dawn Age'],
#  ['Vorwaha Bisonlord', 'Dara Happa'],
#  ['Vorwaha Bisonlord', 'Prax'],
#  ['Vorwaha Bisonlord', 'Gbaji Wars'],
#  ['Vosdalings', 'Talastar'],
#  ['Vosdalings', 'Imperial Age'],
#  ['Voshfrei clan', 'Delela'],
#  ['Voshfrei clan', 'Ralios'],
#  ['Voshfrei dynasty', 'Ralios'],
#  ['Vormain', 'Vormain pirates'],
#  ['Vostalakor', 'EWF'],
#  ['Vostasador the Replicator', 'Dorastor'],
#  ['Vostasador the Replicator', 'Broo'],
#  ['Vosten of Erland', 'Dragon Pass'],
#  ['Vosten of Erland', 'Zin List'],
#  ['Vostenuv', 'Vosten of Erland'],
#  ['Vostena Enstalos', 'Vostena'],
#  ['Vostena Enstalos', 'Enstalos'],
#  ['Vostena', 'Dragon Pass'],
#  ['Vostenuv', 'Dragon Pass'],
#  ['Vostena Enstalos', 'Dragon Pass'],
#  ['Vostena', 'Zin List'],
#  ['Vostenuv', 'Zin List'],
#  ['Vostena Enstalos', 'Zin List'],
#  ['Vostor Blacktooth', 'Orindori'],
#  ['Vostor Blacktooth', 'Tarsh'],
#  ['Vostor Blacktooth', 'Fazzur Wideread'],
#  ['Votankiland', 'Balazar (country)'],
#  ['Votanki', 'Balazarings'],
#  ['Votanki', 'Balazar (country)'],
#  ['Voyage of Opening', 'Dormal'],
#  ['Voyage of Opening', 'Solkathi Sea'],
#  ['Voyage of Opening', 'Threestep Islands'],
#  ['Voyage of Opening', 'Handra'],
#  ['Voyage of Opening', 'Kethaela'],
#  ['Vrala', 'Peas'],
#  ['Vrala', 'Vralos'],
#  ['Vrala', 'Umathela'],
#  ['Vralan', 'Theyalan'],
#  ['Vralan', 'Vralos'],
#  ['Vralan', 'Umathela'],
#  ['Vrimak', 'Father of Birds'],
#  ['Father of Birds', 'Vrimak'],
#  ['Vrimakus', 'Vrimak'],
#  ['Vrimakus', 'Eagle'],
#  ['Vrimakus', 'Rinliddi'],
#  ['Vrimakus', 'Portions of Yelm'],
#  ['Vrimakus Cult', 'Rinliddi'],
#  ['New Bird People', 'Rinliddi'],
#  ['New Bird People', 'Vrimakus'],
#  ['Eagle God', 'Vrimakus'],
#  ['Vrimakus', 'Eagle God'],
#  ['Vrimakus Cult', 'Vrimakus'],
#  ['Vrimakus', 'Vrimakus Cult'],
#  ['Vrimakus Cult', 'New Bird People'],
#  ['Vrok Hawk', 'Dayzatar'],
#  ['Vrok Hawk', 'Yelmalio'],
#  ['Vronkal', 'Vronkali'],
#  ['Vronkal', 'Green Elves'],
#  ['Vronkali', 'Vronkal'],
#  ['Vronkali', 'Green Elves'],
#  ['Vronkali', 'Conifers'],
#  ['Vrop', 'Taluk Tabanos'],
#  ['Vrop', 'Tarien'],
#  ["Vulture's Country", 'Vulture Country'],
#  ['Vuranostum, Sons of', 'Dara Happa'],
#  ['Vuranostum, the Handsome Equestrian', 'Vuranostum'],
#  ['Vuranostum, Sons of', 'Vuranostum'],
#  ['Vuranostrum', 'Vuranostum'],
#  ['Horse Sun', 'Vuranostrum'],
#  ['Horse Sun', 'Hyalor'],
#  ['Vuranostrum', 'Dawn Age'],
#  ['Vuranostum', 'Vuranostrum'],
#  ['Vurgunzol', 'Vurgunzon'],
#  ['Vurgunzon', 'Kitori'],
#  ['Vustria', 'Ralios'],
#  ['Vyran, Queen of Castle Blue', 'Vyran'],
#  ['Vyran, Queen of Castle Blue', 'Castle Blue'],
#  ['Queen of Castle Blue', 'Vyran'],
#  ['Vyran', 'Charmain'],
#  ['Vyrope', 'Dorasta Shrine'],
#  ['Vyrope', 'Kalasmas Kortalosson'],
#  ['Vyrope', 'Dorasta'],
#  ['Vyrope', 'Dawn Age'],
#  ['Vithela Wind', 'Veldru'],
#  ["Vivamort's Castle", 'Elder Wilds'],
#  ['Voice of Atyar', 'Atyar'],
#  ['Sentanos', 'Ralios'],
#  ['Sentanos', 'Safelster'],
#  ['Sentanos', 'Tortun'],
#  ['Sentanos', 'Syran'],
#  ['Sentanos', 'Lady Erengazor'],
#  ['Sentanos', 'Proven Appearance of Arkat Movement'],
#  ['Ryzel', 'Wenelia'],
#  ['Ryzel', 'Inhuman King'],
#  ['Rye', 'Frona'],
#  ['Ruts, Wheel', 'Sun County'],
#  ['Rusty Healing Kelp', 'Tholaina'],
#  ['Rusticus of Two Tomes', 'Raibanth Wisdom Temple'],
#  ['Rusticus of Two Tomes', 'Skyfall Lake'],
#  ['Ubiquus', 'Raibanth Wisdom Temple'],
#  ['Ubiquus', 'Skyfall Lake'],
#  ['Rusticus of Two Tomes', 'Ubiquus'],
#  ['Varanorlanth', 'Orlanth'],
#  ['Varanorlanth', 'Orlanth Adventurous'],
#  ['Rurudram', 'Varanorlanth'],
#  ['Velhara', 'Lady of the Wild'],
#  ['Velhara', 'Varanorlanth'],
#  ['Velhara', 'Five Majestic Beasts'],
#  ['Rurudram', 'Velhara'],
#  ['Rurudram', 'Five Majestic Beasts'],
#  ['Great Horned Beetle', 'Five Majestic Beasts'],
#  ['Great Horned Beetle', 'Varanorlanth'],
#  ['Great Horned Beetle', 'Rurudram'],
#  ['Rurudram', 'Great Horned Beetle'],
#  ['Rurudram', 'Sashaka'],
#  ['Boat', 'Diros'],
#  ['Boat', 'Kogag'],
#  ['Boat', 'Varanorlanth'],
#  ['Boat', 'Rurudram'],
#  ['Rurudram', 'Boat'],
#  ['Ruric the Feisty', 'Ruric Runespear'],
#  ['Ruric Runespear', 'Ruric the Feisty'],
#  ['Runthing', 'Rasout'],
#  ['Runthing', 'Silver Deer'],
#  ['Running Nose', 'Maslo'],
#  ['Running Nose', 'Trickster'],
#  ['Running Nose', 'Changer, the'],
#  ['Running Fox', 'Monrogh'],
#  ['Running Fox', 'Sartar'],
#  ['Runnel River', 'Esrolia'],
#  ['Runnel River', 'Holy Country'],
#  ['Runi Darkwind', 'Rokheart Veinseeker'],
#  ['Runi Darkwind', 'Greatway'],
#  ['Runi Darkwind', 'Mostali'],
#  ['Dwarf', 'Dwarves'],
#  ['Runi Darkwind', 'Dwarf'],
#  ['Dwarf', 'Dwarfs'],
#  ['Runes, Orlanthi', ' Runes'],
#  ['Runes, Malkioni', ' Runes'],
#  ['Runes, Kralori', ' Runes'],
#  ['Runes, God Learner', ' Runes'],
#  ['Runes, Dara Happan', ' Runes'],
#  ['RuneQuest Sight', 'God Learners'],
#  ['RuneQuest Sight', 'Imperial Age'],
#  ['Runegate Tribe', 'Rune Gate Fort'],
#  ['Runegate Tribe', 'Runegate'],
#  ['Runegate Tribe', 'Runegate Triarchy'],
#  ['Runegate Tribe', 'Hyaloring Triarchy'],
#  ['Runegate Tribe', 'Enhyli'],
#  ['Runegate Triarchy', 'Runegate'],
#  ['Runegate Triarchy', 'Runegate Tribe'],
#  ['Runegate Triarchy', 'Hyaloring Triarchy'],
#  ['Runegate Triarchy', 'Enhyl'],
#  ['Runegate', 'Colymar Tribal Lands'],
#  ['Runegate', 'Colymar (tribe)'],
#  ['Runegate', 'Creek River'],
#  ['Runegate', 'Jarolar'],
#  ['Runegate', 'Crimson Bat'],
#  ['Runegate', 'Hyaloring Triarchy'],
#  ['Runegate', 'Runegate, Battle of'],
#  ['Rune, Water', 'Zaramaka'],
#  ['Rune, Water', 'Magasta'],
#  ['Rune, Truth', 'Orenoar'],
#  ['Rune, Truth', 'Dayzatar'],
#  ['Rune, Stasis', 'Acos'],
#  ['Rune, Stasis', 'Mostal'],
#  ['Rune, Spirit', 'Horned Man'],
#  ['Rune, Shadow', 'Moorgarki'],
#  ['Rune, Shadow', 'Gorgorma'],
#  ['Rune, Shadow', 'Argan Argar'],
#  ['Rune, Shadow', 'Xentha'],
#  ['Rune, Plant', 'Flamal'],
#  ['Rune, Movement', 'Larnste'],
#  ['Rune, Movement', 'Mastakos'],
#  ['Rune, Movement', 'Vinga'],
#  ['Rune, Movement', 'Orlanth'],
#  ['Rune, Movement', 'Issaries'],
#  ['Rune, Movement', 'Sartar (hero)'],
#  ['Rune, Movement', 'Change'],
#  ['Rune, Moon', 'Sedenya'],
#  ['Rune, Moon', 'Rufelza'],
#  ['Rune, Moon', 'Red Goddess'],
#  ['Rune, Mastery', 'Arachne Solara'],
#  ['Rune, Man', 'Grandfather Mortal'],
#  ['Rune, Man', 'Daka Fal'],
#  ['Rune, Magic', 'Arachne Solara'],
#  ['Rune, Luck', 'Asrelia'],
#  ['Rune, Law', 'Invisible God'],
#  ['Rune, Infinity', 'Arachne Solara'],
#  ['Rune, Illusion', 'Tylenea'],
#  ['Rune, Illusion', 'Eurmal'],
#  ['Rune, Illusion', 'Donandar'],
#  ['Rune, Hunger', 'Krarsht'],
#  ['Rune, Hunger', 'Vivamort'],
#  ['Rune, Heat', 'Lodril'],
#  ['Rune, Harmony', 'Chalana Arroy'],
#  ['Rune, Harmony', 'Harana Ilor'],
#  ['Rune, Fire', 'Aether'],
#  ['Rune, Fire', 'Yelm'],
#  ['Rune, Fate', 'Ty Kora Tek'],
#  ['Rune, Earth', 'Ga'],
#  ['Rune, Earth', 'Ernalda'],
#  ['Rune, Dragonewt', 'Dragonewts'],
#  ['Rune, Dragon', 'Godunya'],
#  ['Rune, Disorder', 'Ratslaff'],
#  ['Rune, Disorder', 'Bolongo'],
#  ['Rune, Disorder', 'Storm Bull'],
#  ['Rune, Disorder', 'Eurmal'],
#  ['Rune, Death', 'Kargan Tor'],
#  ['Rune, Death', 'Humakt'],
#  ['Rune, Darkness', 'Nakala'],
#  ['Rune, Darkness', 'Subere'],
#  ['Rune, Dark Earth', 'Maran Gor'],
#  ['Rune, Dark Earth', 'Babeester Gor'],
#  ['Rune, Communication', 'Issaries'],
#  ['Rune, Communication', 'Argan Argar'],
#  ['Rune, Communication', 'Etyries'],
#  ['Rune, Cold', 'Himile'],
#  ['Rune, Chaos', 'Primal Chaos'],
#  ['Rune, Beast', 'Hykim'],
#  ['Rune, Air', 'Umath'],
#  ['Rune, Air', 'Orlanth'],
#  ['Rune Gate Fort', 'Runegate'],
#  ['Rune, Fertility', 'Uleria'],
#  ['Runaway Woman', 'Tarkalor'],
#  ['Runaway Woman', 'Saronil'],
#  ['Soaratta', 'Runaway Woman'],
#  ['Soaratta', 'Tarkalor'],
#  ['Soaratta', 'Saronil'],
#  ['Soaratta the Reddest', 'Soaratta'],
#  ['Soaratta', 'Soaratta the Reddest'],
#  ['Soaratta the Reddest', 'Runaway Woman'],
#  ['Run Free Gangs', 'Bright Empire'],
#  ['Run Free Gangs', 'Talastar'],
#  ['Run Free Gangs', 'Gbaji Wars'],
#  ['Run Free Gangs', 'Dawn Age'],
#  ['Run Free Gangs', 'Arkat'],
#  ['Rules of Fort Wrath', 'Fort Wrath'],
#  ['Rules of Fort Wrath', 'Ralzakark'],
#  ['Rules of Fort Wrath', 'Dorastor'],
#  ['Ruined City, The', 'Suam Chow'],
#  ['Ruined City, The', 'Kralorela'],
#  ['Ruined City, The', 'Goropheng'],
#  ['Ruined City', 'Goropheng'],
#  ['Ruined City', 'Ruined City, The'],
#  ['Ruidhy', 'Joh Mith'],
#  ['Ruidhy', 'Dalfar Skyseeker'],
#  ['Ruidhy', 'Balazar (country)'],
#  ['Rugbagian', 'Pharnastes Rugbagian'],
#  ['Rugbagian', 'Etyries'],
#  ['Rugbagian', 'Pavis City'],
#  ['Rugbagian', 'Pavis County'],
#  ['Rug of Peace', 'Orventili'],
#  ['Rug of Peace', 'Ernalda'],
#  ['Rufelza Cult', 'Rufelza'],
#  ['Rufelza Cult', 'Rinliddi'],
#  ['Rufelza Cult', 'Red Goddess'],
#  ['Rufelza Cult', 'Phases of the Moon'],
#  ['Rufelza Cult', 'Lunar Empire'],
#  ['Rufelza Cult', 'Dara Happa'],
#  ['Rufelza Cult', 'First Blessed'],
#  ['Rufelza Cult', 'Sedenya'],
#  ['Rufelza Cult', 'Red Moon'],
#  ['Rufelza Cult', 'Lunar Goddess'],
#  ['Rufelza', 'Red Moon'],
#  ['Rufelza', 'Rufelza Cult'],
#  ['Rufelza', 'Lunar Empire'],
#  ['Rufelza', 'Sedenya'],
#  ['Rufelza', 'Natha'],
#  ['Rufelza', 'Phasing Moon'],
#  ['Rufdayen', 'Verithurusa'],
#  ['Rufdayen', 'Red Goddess'],
#  ['Rufdayen', 'Storm Age'],
#  ['Rudman', 'Hazard Fort'],
#  ['Rudman', 'Renekot the Stone'],
#  ['Rudman', 'Riskland'],
#  ['Rudman', 'Dorastor'],
#  ['Rudder', 'Ship Building'],
#  ['Ruby-throated Hummingbird', 'Carresh'],
#  ['Ruby-throated Hummingbird', 'Sheng Seleris'],
#  ['Ruby-throated Hummingbird', 'Red Emperor'],
#  ['Ruby-throated Hummingbird', 'Gardens of Carresh'],
#  ['Ruby Tree', 'Laskal'],
#  ['Ruby Tree', 'Dinal'],
#  ['Ruby Tree', 'Errinoru Jungle'],
#  ['Ruby Tree', 'Pamaltela'],
#  ['Rubble, The', 'Pavis City'],
#  ['Rubble, The', 'Pavis Rubble'],
#  ['Rubble, The', 'Big Rubble'],
#  ['Rubble Trolls', 'Javis Gan'],
#  ['Rubble Trolls', 'Geras Shag'],
#  ['Rubble Trolls', 'Gerak Kag'],
#  ['Rubble Trolls', 'Big Rubble'],
#  ['Rubble Trolls', 'Pavis City'],
#  ['Rubble, The', 'Rubble'],
#  ['Rozgali Sea', 'Prax'],
#  ['Rozgali Sea', 'Wastes'],
#  ['Rozgali Sea', 'Choralinthor Bay'],
#  ['Rozgali Sea', 'Mirrorsea Bay'],
#  ['Rozgali Sea', 'Threestep Islands'],
#  ['Rozgali Sea', 'Teshnos'],
#  ['Rozgali Sea', 'Melib'],
#  ['Rozgali Sea', 'Zola Fel'],
#  ['Rozgali Sea', 'Seolinthur'],
#  ['Rozgali Sea', 'Ludoch'],
#  ['Rozgali Sea', 'Homeward Ocean'],
#  ['Rozgali Coast', 'Rozgali'],
#  ['Rozgali Coast', 'Rozgali Sea'],
#  ['Rozgali', 'Rozgali Coast'],
#  ['Rozgali', 'Rozgali Sea'],
#  ['Rozgali', 'Sedlazam'],
#  ['Rozgali', 'Choralinthor'],
#  ['Rozgali', 'Threestep Islands'],
#  ['Royal Treasurer', 'Seshnela'],
#  ['Royal Marshall', 'Seshnela'],
#  ['Royal Marshal', 'Seshnela'],
#  ['Royal Marshal', 'Royal Marshall'],
#  ['Royal Justiciar', 'Seshnela'],
#  ['Royal Justiciar', 'Guilmarn'],
#  ['Royal Horned Caterpillar', 'Giant Insects'],
#  ['Royal Highway', 'Heortland'],
#  ['Royal Highway', 'Sartar'],
#  ['Rowl', 'Dog'],
#  ['Rowf Guards', 'Banadal of Ger'],
#  ['Rowf Guards', 'Balazarings'],
#  ['Rowf Guards', 'EWF'],
#  ['Rowf Guards', 'Jajalarings'],
#  ["Rowdy Djoh Lo's", 'Pavis City'],
#  ["Rowdy Djoh Lo's", 'Snakefang'],
#  ['Rowdril', 'Dog'],
#  ['Rowdril', 'Saird'],
#  ['Rowdril', 'Verenmars'],
#  ['Rowdril', 'Ensoval'],
#  ['Rowdril', 'Jajagapa'],
#  ['Rowdril', 'Jajagappa'],
#  ['Rowdril', 'Jajalarings'],
#  ['War Hounds', 'Rowdril'],
#  ['War Hounds', 'Dog'],
#  ['Rowdril', 'War Hounds'],
#  ['Father Dog', 'Rowdril'],
#  ['Rowdril', 'Father Dog'],
#  ['Roundstone', 'Sartar'],
#  ['Roundlakes', 'Roundlake Mountains'],
#  ['Roundlakes', 'Dagori Inkarth'],
#  ['Roundlake Mountains', 'Roundlakes'],
#  ['Roundlake Mountains', 'Dagori Inkarth'],
#  ['Rotground Marshes', 'Dorastor'],
#  ['Rotground', 'Dorastor'],
#  ['Rotground Marshes', 'Rotground'],
#  ['Rotground', 'Rotground Marshes'],
#  ['Rotground', 'Chaos'],
#  ['Rostand the Speaker', 'Dragon Speech'],
#  ['Rostand the Speaker', 'Auld Wyrmish (language)'],
#  ['Enjossi', 'Balmyr'],
#  ['Enjossi', 'Rostakos'],
#  ['Father Salmon', 'Enjossi'],
#  ['Enjossi', 'Stream River'],
#  ['Enjossi', 'River, The'],
#  ['Enjossi', 'New River'],
#  ['Salmon', 'Enjossi'],
#  ['Father Salmon', 'Salmon'],
#  ['Salmon', 'Father Salmon'],
#  ['Enjossi', 'Colymar (tribe)'],
#  ['Enjossi', 'Enjossi Clan'],
#  ['Enjossi Clan', 'Enjossi'],
#  ['Enjossi Clan', 'Balmyr'],
#  ['Enjossi Clan', 'Salmon'],
#  ['Enjossi Clan', 'Stream River'],
#  ['Enjeem Leopard', 'Leopard'],
#  ['Enjeem Leopard', 'Tarsh'],
#  ['Enjeem Leopard', 'Hero Wars'],
#  ['Enjeem Leopard', 'Dragon Pass'],
#  ['Enjeem Leopard', 'Zin List'],
#  ['Enjeem', 'Hero Wars'],
#  ['Enjeem', 'Leopard'],
#  ['Enjeem', 'Enjeem Leopard'],
#  ['Enjeem', 'Zin List'],
#  ['Enjeem', 'Tarsh'],
#  ['Enjata Mo', 'Pamaltela'],
#  ['Enjata Mo', 'KataMoripi'],
#  ['Enjata Mo', 'Sky Witches'],
#  ['Enjata Mo', 'Storm Era'],
#  ['Enjata Mo', 'Cronisper'],
#  ['Enjata-Mo', 'Enjata Mo'],
#  ['Seven Falls', 'Enjossi'],
#  ['Seven Falls', 'Rostakos'],
#  ['Seven Falls', 'Sartar'],
#  ['Seven Falls', 'Creekstream River'],
#  ['Rostakos, King of the Colymar', 'Jenstali'],
#  ['Rostakos, King of the Colymar', 'Colymar (tribe)'],
#  ['Salmon Rite', 'Enjossi'],
#  ['Salmon Rite', 'Salmon'],
#  ['Salmon Rite', 'Seven Falls'],
#  ['Rostakos, King of the Colymar', 'Salmon Rite'],
#  ['Rostakos, King of the Colymar', 'Sartar'],
#  ['Rostakos, King of the Colymar', 'Termites'],
#  ['Rostakos, King of the Colymar', 'Woodpecker'],
#  ['Salmon Man', 'Enjossi'],
#  ['Rostakos', 'Yoran'],
#  ['Rostakos', 'Entan'],
#  ['Rostakos', 'Argrath'],
#  ['Rostakos', 'Rostakos, King of the Colymar'],
#  ['Roskoth', 'Longsi Land'],
#  ['Roskoth', 'Malthin River'],
#  ['Roskoth', 'Esrolia'],
#  ["Rory's Well", 'Sun County'],
#  ["Rory's Well", 'Prax'],
#  ['Rory', 'Griselda'],
#  ['Rory', 'Lucky Eddi'],
#  ['Rory', 'Rubble'],
#  ['Rory', 'Alone'],
#  ['Rope of Red Harkenkarth', 'Aliss Boatmen'],
#  ['Rope of Red Harkenkarth', 'Aliss River'],
#  ['Rope of Red Harkenkarth', 'Feofaxia'],
#  ['Rope of Red Harkenkarth', 'Errinoru Jungle'],
#  ['Rope of Red Harkenkarth', 'Pamaltela'],
#  ['Rootless Elves', 'Aldrya'],
#  ['Ronthal Bay', 'Loskalm'],
#  ['Ronthal Bay', 'Fronela'],
#  ['Ronthal Bay', 'Winterwood'],
#  ['Ronthal Bay', "Ygg's Isles"],
#  ['Ronthal Bay', 'Closing'],
#  ['Ronswood', 'Elf Sea'],
#  ['Ronswood', 'Elder Wilds'],
#  ['Ronswood', 'Balazar (country)'],
#  ['Ronswood', 'Dangerground'],
#  ['Ronegarth', 'Raus Fort'],
#  ['Ronegarth', 'Duke Raus'],
#  ['Ronegarth', 'Grantlands'],
#  ['Ronegarth', 'Zola Fel Valley'],
#  ['Roneer the Hue', 'Sable Riders'],
#  ['Roneer the Hue', 'Pavis'],
#  ['Rone', 'Duke Raus'],
#  ['Rone', 'Ronegarth'],
#  ['Rone', 'Kostaddi'],
#  ['Rone', 'Lunar Empire'],
#  ['Rone', 'Dart Competitions'],
#  ['Ronance', 'Paps'],
#  ['Ronance', 'Earth Spirits'],
#  ['Ronance', 'Eiritha'],
#  ['Ronance', 'Golden Age'],
#  ['Ronance', 'Chariot'],
#  ['Ronance', 'Serpent'],
#  ['Romal', 'Cave Trolls'],
#  ['Romal', 'Pocharngo'],
#  ['Rolling Thunder', 'Horse'],
#  ['Rolling Thunder', 'Finovan'],
#  ['Rokheart Veinseeker', 'Greatway'],
#  ['Rokheart Veinseeker', 'Dwarf'],
#  ['Rokheart Veinseeker', 'Balazar (country)'],
#  ['Rokarism', 'Malkionism'],
#  ['Rokarism', 'Seshnela'],
#  ['Rokarism', 'Rokar'],
#  ['Rokarism', 'Leplain'],
#  ['Rokarism', 'Ecclesiarch of Rokari Church'],
#  ['Rokarism', 'Rokari'],
#  ['Rokarism', 'Rokari Church'],
#  ['Rokarism', 'Rokari Caste System'],
#  ['Rokarism', 'Rokari College of Magic'],
#  ['Rokarism', 'Chivalry'],
#  ['Rokarism', 'Rokari Ecclesiarch'],
#  ['Rokarism', 'Bailifes'],
#  ['Rokarian', 'Rokari'],
#  ...]

# %%
# Normally, you could graph this directly, but the graph is too big.  Don't run this.

#pos=nx.spring_layout(G)

# %%
# Or this

#nx.draw_networkx_nodes(G, pos)
#nx.draw_networkx_edges(G, pos)

# %%
# Or this

#plt.show()

# %%
# Export to JSON format
from networkx.readwrite import json_graph

d = json_graph.node_link_data(G)
json.dump(d, open('/Users/christopherallison/Documents/Coding/Python/Network Graph/force/Glorantha.json', 'w'))

# %%
# Write to Graphml format
nx.write_graphml(G,"international_aid_2013.graphml")

# %% [markdown]
# ### Now open up Gephi and play with your data!
